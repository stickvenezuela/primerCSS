# %% [markdown]
# ### fundamentos epicos
# * variables
# * Operadores matematicos
# * Operadores logicos
# * Operadores de comparacion
# * estructuras de control
#     - Condicionales
#     - Ciclo finito: for
#     - Ciclo infinityo: while
#     - funciones
# * estructuras de datos
#     - cadenas de caracters: string
#     - numeros enteros
#     - numeros decimales
#     - listas
#     - diccionarios
#     - tuplas

# %%
print("holaqaa *inserte opening de death note*")
# Out:
# holaqaa *inserte opening de death note*

# %%
# Variables
name = "Ernesto"
last_name = "Loquendero777"
effe = "when ases tus momos en un curso"

# %%
print(name, last_name)
print(effe)
# Out:
# Ernesto Loquendero777
# when ases tus momos en un curso

# %%
number_1 = 20
number_2 = 5

# %%
result = number_1 + number_2

# %%
print(result)
# Out:
# 25

# %%
result_res = number_1 - number_2

# %%
result_mul = number_1 * number_2
result_div = number_1 / number_2

# %%
type(result_mul)
# Out:
# int

# %%
import random

def get_user_name():
    return input("Enter your name: ")

def get_user_choice():
    user_choice = input("Enter your choice (rock, paper, scissors): ").lower()
    while user_choice not in ["rock", "paper", "scissors"]:
        user_choice = input("Invalid choice. Please enter rock, paper, or scissors: ").lower()
    return user_choice

def get_computer_choice():
    return random.choice(["rock", "paper", "scissors"])

def determine_winner(user_choice, computer_choice):
    if user_choice == computer_choice:
        return "It's a tie!"
    elif (user_choice == "rock" and computer_choice == "scissors") or \
         (user_choice == "paper" and computer_choice == "rock") or \
         (user_choice == "scissors" and computer_choice == "paper"):
        return "You win!"
    else:
        return "You lose!"

def play_game():
    user_name = get_user_name()
    user_choice = get_user_choice()
    computer_choice = get_computer_choice()
    print(f"{user_name}, you chose: {user_choice}")
    print(f"Computer chose: {computer_choice}")
    result = determine_winner(user_choice, computer_choice)
    print(result)

if __name__ == "__main__":
    play_game()
# Out:
# ernesto, you chose: rock
# Computer chose: rock
# It's a tie!
